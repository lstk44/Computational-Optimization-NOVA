# %% [markdown]
# # Imports

# %%
# Data
from data                   import commodities, nutrients
# Importing libraries
from random                 import shuffle, choice, sample, random, uniform
from copy                   import deepcopy
from operator               import attrgetter
import matplotlib.pyplot    as plt
import numpy                as np
import pandas               as pd
# Importing classes and functions
from individual             import Individual                                       #
from population             import Population                                       #
from selection              import roulette, ranked, tournament                     #
from variation              import crossover, mutation                              #
from fitness                import get_fitness                                      #

# %% [markdown]
# # Functions

# %%
def evaluation(population_size, evolve_parameters, iterations=30):
    history = {}
    items_combined = []
    products = []
    populations = []
    for i in range(iterations):
        # Monkey Patching
        Individual.get_fitness = get_fitness
        # create initial population
        pop = Population(size=population_size, optim="min", sol_size=len(commodities), valid_set=list(range(2)), replacement=True)
        # evolve
        pop.evolve(
            select = evolve_parameters['select'],
            tournament_k = evolve_parameters['tournament_k'],
            gens = evolve_parameters['gens'], 
            mut_prob = evolve_parameters['mut_prob'],
            mutate = evolve_parameters['mutate'],
            mut_type = evolve_parameters['mut_type'],
            bit_flips = evolve_parameters['bit_flips'],
            xo_prob = evolve_parameters['xo_prob'],
            crossover = evolve_parameters['crossover'],
            xo_type = evolve_parameters['xo_type'],
            elitism = evolve_parameters['elitism']
        )
        
        history[i] = pop.history_fitness
        items_combined += pop.history_products
        products.append(pop.history_products)
        populations.append(pop)

    product_count = {i:items_combined.count(i) for i in set(items_combined)}

    min_individual = np.argmin(np.array(list(history.values()))[:,-1])
    table = {}
    for i in products[min_individual]:
        table[i] = commodities[i][0]
    table['SUM'] = round(sum(table.values()),4)

    best_of_individuals = (np.array(list(history.values()))[:,-1])
    print(f'Average - Fitness: {round(np.mean(best_of_individuals),4)} USD$')
    print(f'Standard Deviation - Fitness: {round(np.std(best_of_individuals),4)} USD$')
    
    return history, product_count, table, populations[min_individual]

def plot_results(results, product_count, table, nutri, nutrients=nutrients):
    fig = plt.figure(figsize=(15, 15))
    gs = fig.add_gridspec(nrows=2, ncols=2)

    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    # ax3 = fig.add_subplot(gs[1, :])
    ax3 = fig.add_subplot(gs[1, 0])
    ax4 = fig.add_subplot(gs[1, 1])

    # fitness history lineplot
    for i in results.keys():
        ax1.plot(list(results.values())[i-1], label=f'Run {i}')
    ax1.plot(np.mean(list(results.values()), axis=0), color='black', label='Mean', linestyle='--', linewidth=4)
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax1.set_title('Fitness History')
    ax1.set_xlabel('Generation')
    ax1.set_ylabel('Fitness ($)')
    ax1.legend(ncol=2, fontsize=8, loc='upper right')

    # product count barplot
    product_count_sorted = {k: v for k, v in sorted(product_count.items(), key=lambda item: item[1])[-10:]}
    prods = list(product_count_sorted.keys())
    vals = list(product_count_sorted.values())
    ax2.barh(prods, vals)
    for i, v in enumerate(vals):
        if len(prods[i]) <= v*4:
            # label fits inside bar
            ax2.text(v / 2, i, prods[i], ha='center', va='center')
        else:
            # label doesn't fit inside bar, place at edge
            ax2.text(v + 0.5, i, prods[i], ha='left', va='center')
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['left'].set_visible(False)
    ax2.set_yticks([])
    ax2.set_yticklabels([])
    ax2.set_title('Most Common Optimal Products (Top 10)')
    ax2.set_xlabel('Count')

    # best solution table
    df = pd.DataFrame(table, index=['Price ($)']).T.reset_index().rename(columns={'index':'Product'})
    cols = [["w","w"] for i in range(len(df))]
    cols[-1] = ["#C5C7C5","#C5C7C5"]
    table = ax3.table(cellText=df.values,colLabels=df.columns,rowLabels=df.index,loc='center',cellLoc='center', cellColours=cols)
    table.auto_set_font_size(False)
    table.set_fontsize(7)
    # table.scale(1, 1.5)
    ax3.get_xaxis().set_visible(False)
    ax3.get_yaxis().set_visible(False)
    ax3.set_title('Best Solution')

    # nutrients of best solution
    generations = list(range(len(nutri.history_calories)))
    ax4.plot(generations, nutri.history_calories, label='Calories (kcal)', c='red')
    ax4.axhline(y = nutrients['Calories (kcal)'], linestyle = ':', c='red')
    ax4.plot(generations, nutri.history_protein, label='Protein (g)', c='green')
    ax4.axhline(y = nutrients['Protein (g)'], linestyle = ':', c='green')
    ax4.plot(generations, nutri.history_carbohydrates, label='Carbohydrates (g)', c='blue')
    ax4.axhline(y = nutrients['Carbohydrates (g)'], linestyle = ':', c='blue')
    ax4.plot(generations, nutri.history_fat, label='Total Fat (g)', c='orange')
    ax4.axhline(y = nutrients['Total Fat (g)'], linestyle = ':', c='orange')
    ax4.plot(generations, nutri.history_sodium, label='Sodium (mg)', c='magenta')
    ax4.axhline(y = nutrients['Sodium (mg)'], linestyle = ':', c='magenta')
    ax4.spines['top'].set_visible(False)
    ax4.spines['right'].set_visible(False)
    ax4.set_yscale("log")
    ax4.set_xlabel("Generations")
    ax4.set_ylabel("Nutrition Values")
    ax4.set_title("Nutrition Curves")
    ax4.legend(loc ="upper right", fontsize="8")

    plt.show()

# %% [markdown]
# # 1st Run
#
# |Parameter                 | Value             |
# |--------------------------|-------------------|
# |Generations per Iterarion:| 30                |
# |Population Size:          | 500               |
# |Selection:                | Roulette          |
# |Mutation:                 | Single-Bit-Flip   |
# |Crossover:                | One-Point         |
# |Elitism:                  | True              |

# %%
evolve_parameters = {
    "select": roulette,
    "tournament_k": None,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "single_bit_flip",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "one-point",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 104.054 USD$
# Standard Deviation - Fitness: 8.7883 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|104.054 USD$ |
# |Std. Fitness|8.7883 USD$  |
#
# - Algorithm decreases slowly
# - Volatile curves
# - No convergence reached
#
# ---

# %% [markdown]
# # 2nd Run
#
# |Parameter                 | Value             |
# |--------------------------|-------------------|
# |Generations per Iterarion:| 30                |
# |Population Size:          | 500               |
# |Selection:                | **Ranked**        |
# |Mutation:                 | Single-Bit-Flip   |
# |Crossover:                | One-Point         |
# |Elitism:                  | True              |
#
# Changing Selection from **Roulette** to **Ranked**

# %%
evolve_parameters = {
    "select": ranked,
    "tournament_k": None,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "single_bit_flip",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "one-point",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 14.8613 USD$
# Standard Deviation - Fitness: 1.3221 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|14.8613 USD$ |
# |Std. Fitness|1.3221 USD$  |
#
# Changing the selection algorithm helps speeding up the minimization
#
# ---

# %% [markdown]
# # 3rd Run
#
# |Parameter                 | Value             |
# |--------------------------|-------------------|
# |Generations per Iterarion:| 30                |
# |Population Size:          | 500               |
# |Selection:                | **Tournament**    |
# |Mutation:                 | Single-Bit-Flip   |
# |Crossover:                | One-Point         |
# |Elitism:                  | True              |
#
# Changing Selection from **Ranked** to **Tournament** (k = 5)

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "single_bit_flip",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "one-point",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 13.0637 USD$
# Standard Deviation - Fitness: 0.9211 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|13.0637 USD$ |
# |Std. Fitness|0.9211 USD$  |
#
# By only manipulating the **Selection Parameter** (ceteris paribus) **Tournament** seems to minimizes the fitness function the fastest
#
# ---

# %% [markdown]
# # 4th Run
#
# |Parameter                 | Value             |
# |--------------------------|-------------------|
# |Generations per Iterarion:| 30                |
# |Population Size:          | 500               |
# |Selection:                | Tournament        |
# |Mutation:                 | Single-Bit-Flip   |
# |Crossover:                | **Five-Point**    |
# |Elitism:                  | True              |
#
# Changing Crossover from **One-Point** to **Five-Point**

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "single_bit_flip",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "five-point",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.6437 USD$
# Standard Deviation - Fitness: 0.3537 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.6437 USD$ |
# |Std. Fitness|0.3537 USD$  |
#
# ---

# %% [markdown]
# # 5th Run
#
# |Parameter                 | Value             |
# |--------------------------|-------------------|
# |Generations per Iterarion:| 30                |
# |Population Size:          | 500               |
# |Selection:                | Tournament        |
# |Mutation:                 | Single-Bit-Flip   |
# |Crossover:                | **Ten-Point**     |
# |Elitism:                  | True              |
#
# Changing Crossover from **Five-Point** to **Ten-Point**

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "single_bit_flip",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "ten-point",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.5177 USD$
# Standard Deviation - Fitness: 0.2141 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.5177 USD$ |
# |Std. Fitness|0.2141 USD$  |
#
# ---

# %% [markdown]
# # 6th Run
#
# |Parameter                 | Value             |
# |--------------------------|-------------------|
# |Generations per Iterarion:| 30                |
# |Population Size:          | 500               |
# |Selection:                | Tournament        |
# |Mutation:                 | Single-Bit-Flip   |
# |Crossover:                | **Uniform**       |
# |Elitism:                  | True              |
#
# Changing Crossover from **Ten-Point** to **Uniform**

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "single_bit_flip",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "uniform",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.4747 USD$
# Standard Deviation - Fitness: 0.2186 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.4747 USD$ |
# |Std. Fitness|0.2186 USD$  |
#
# ---

# %% [markdown]
# # 7th Run
#
# |Parameter                 | Value                           |
# |--------------------------|---------------------------------|
# |Generations per Iterarion:| 30                              |
# |Population Size:          | 500                             |
# |Selection:                | Tournament                      |
# |Mutation:                 | **Complete_Bit_Flip**           |
# |Crossover:                | Uniform                         |
# |Elitism:                  | True                            |
#
# Changing Mutation from **Single-Bit-Flip** to **Complete_Bit_Flip**

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "complete_bit_flip",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "uniform",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.5777 USD$
# Standard Deviation - Fitness: 0.2547 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.5777 USD$ |
# |Std. Fitness|0.2547 USD$  |
#
# ---

# %% [markdown]
# # 8th Run
#
# |Parameter                 | Value                           |
# |--------------------------|---------------------------------|
# |Generations per Iterarion:| 30                              |
# |Population Size:          | 500                             |
# |Selection:                | Tournament                      |
# |Mutation:                 | **Single_Swap_Mutation**        |
# |Crossover:                | Uniform                         |
# |Elitism:                  | True                            |
#
# Changing Mutation from **Complete_Bit_Flip** to **Single_Swap_Mutation**

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "single_swap_mutation",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "uniform",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.4703 USD$
# Standard Deviation - Fitness: 0.2152 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.4703 USD$ |
# |Std. Fitness|0.2152 USD$  |
#
# ---

# %% [markdown]
# # 9th Run
#
# |Parameter                 | Value                           |
# |--------------------------|---------------------------------|
# |Generations per Iterarion:| 30                              |
# |Population Size:          | 500                             |
# |Selection:                | Tournament                      |
# |Mutation:                 | **Multiple_Bit_Flip_Mutation**  |
# |Crossover:                | Uniform                         |
# |Elitism:                  | True                            |
#
# Changing Mutation from **Single_Swap_Mutation** to **Multiple_Bit_Flip_Mutation**

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "multiple_bit_flip_mutation",
    "bit_flips": 5,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "uniform",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.4473 USD$
# Standard Deviation - Fitness: 0.1836 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.4473 USD$ |
# |Std. Fitness|0.1836 USD$  |
#
# ---

# %% [markdown]
# # 10th Run
#
# |Parameter                 | Value                           |
# |--------------------------|---------------------------------|
# |Generations per Iterarion:| 30                              |
# |Population Size:          | 500                             |
# |Selection:                | Tournament                      |
# |Mutation:                 | **Scramble_Mutation**           |
# |Crossover:                | Uniform                         |
# |Elitism:                  | True                            |
#
# Changing Mutation from **Multiple_Bit_Flip_Mutation** to **Scramble_Mutation**

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 5,
    "gens": 30,
    "mut_prob": 0.2,
    "mutate": mutation,
    "mut_type": "scramble_mutation",
    "bit_flips": None,
    "xo_prob": 0.9,
    "crossover": crossover,
    "xo_type": "uniform",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=500, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.4547 USD$
# Standard Deviation - Fitness: 0.1973 USD$

# %%
plot_results(results, product_count, table, nutri)

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.4547 USD$ |
# |Std. Fitness|0.1973 USD$  |
#
# ---

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# The best model so far was in Run 9 using tournament selection, multiple bit flip mutation and uniform crossover. In this section we aim to further optimize this by tuning some hyperparameters related to the previously mentioned methods and to the genetic algorithm in general.

# %% [markdown]
# To set up the search space we consulted several sources in addition to the input from the lecture to search for the best parameter setting.
#
# Population size: <br>
# https://de.mathworks.com/help/gads/options-in-genetic-algorithm.html<br>
# https://www.tutorialspoint.com/genetic_algorithms/genetic_algorithms_population.htm
#
#
# Tournament size: <br>
# https://wpmedia.wolfram.com/uploads/sites/13/2018/02/09-3-2.pdf<br>
# https://ieeexplore.ieee.org/document/8616614
#
# Mutation probability:<br>
# https://www.tutorialspoint.com/genetic_algorithms/genetic_algorithms_mutation.htm<br>
# https://www.baeldung.com/cs/genetic-algorithms-crossover-probability-and-mutation-probability
#
# Crossover probability:<br>
# https://www.tutorialspoint.com/genetic_algorithms/genetic_algorithms_crossover.htm<br>
# https://www.baeldung.com/cs/genetic-algorithms-crossover-probability-and-mutation-probability

# %%
search_space = {
    "pop_size": [50,100,250,500,750],
    "tournament_k": [3,4,5,6],
    "xo_prob": [0.7, 0.8, 0.9, 0.95],
    "mut_prob": [0.01, 0.1, 0.2, 0.3],
    "bit_flips": [3,5,7]
}

# %%
tuning_results = []
for pop_size in search_space["pop_size"]:
    for k in search_space["tournament_k"]:
        for xo_p in search_space["xo_prob"]:
            for mut_p in search_space["mut_prob"]:
                for flips in search_space["bit_flips"]:
                    print("############### New Parameter Setting ###############")
                    print("pop_size =", str(pop_size)+";", "tournament_k =",str(k)+";","xo_prob =", str(xo_p)+";", "mut_prob =", str(mut_p)+";","bit_flips =", str(flips))
                    evolve_parameters = {
                        "select": tournament,
                        "tournament_k": k,
                        "gens": 30,
                        "mut_prob": mut_p,
                        "mutate": mutation,
                        "mut_type": "multiple_bit_flip_mutation",
                        "bit_flips": flips,
                        "xo_prob": xo_p,
                        "crossover": crossover,
                        "xo_type": "uniform",
                        "elitism": True
                        }
                    results, product_count, table, nutri = evaluation(population_size=pop_size, evolve_parameters=evolve_parameters, iterations=20) # less iterations due to hardware limitations
                    best_of_individuals = (np.array(list(results.values()))[:,-1])
                    avg_fitness = round(np.mean(best_of_individuals),4)
                    tuning_results.append([results, product_count, table, nutri, avg_fitness, [pop_size, k, xo_p, mut_p, flips]])
# Out:
# ############### New Parameter Setting ###############
# pop_size = 50; tournament_k = 3; xo_prob = 0.7; mut_prob = 0.01; bit_flips = 3
# Average - Fitness:
USD$
# ############### New Parameter Setting ###############
# pop_size = 750; tournament_k = 6; xo_prob = 0.95; mut_prob = 0.3; bit_flips = 3
# Average - Fitness: 11.412 USD$
# Standard Deviation - Fitness: 0.1358 USD$
# ############### New Parameter Setting ###############
# pop_size = 750; tournament_k = 6; xo_prob = 0.95; mut_prob = 0.3; bit_flips = 5
# Average - Fitness: 11.3605 USD$
# Standard Deviation - Fitness: 0.1106 USD$
# ############### New Parameter Setting ###############
# pop_size = 750; tournament_k = 6; xo_prob = 0.95; mut_prob = 0.3; bit_flips = 7
# Average - Fitness: 11.4505 USD$
# Standard Deviation - Fitness: 0.1508 USD$

# %%
best_run = tuning_results[np.argmin([x[4] for x in tuning_results])]
print("pop_size =", str(best_run[5][0])+";", "tournament_k =",str(best_run[5][1])+";","xo_prob =", str(best_run[5][2])+";", "mut_prob =", str(best_run[5][3])+";","bit_flips =", str(best_run[5][4]))
best_of_individuals = (np.array(list(best_run[0].values()))[:,-1])
print(f'Average - Fitness: {round(np.mean(best_of_individuals),4)} USD$')
print(f'Standard Deviation - Fitness: {round(np.std(best_of_individuals),4)} USD$')
# Out:
# pop_size = 750; tournament_k = 4; xo_prob = 0.95; mut_prob = 0.1; bit_flips = 5
# Average - Fitness: 11.3055 USD$
# Standard Deviation - Fitness: 0.0963 USD$

# %%
plot_results(best_run[0], best_run[1], best_run[2], best_run[3])
# Out:
# C:\Users\janpa\AppData\Local\Temp\ipykernel_1880\576603859.py:81: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax2.set_yticks([])

# %% [markdown]
# **Conclusion**
#
# |Parameter                 | Value                           |
# |--------------------------|---------------------------------|
# |Generations per Iterarion:| 30                              |
# |Population Size:          | 750                             |
# |Selection:                | Tournament                      |
# |Tournament Size:          | 4                               |
# |Mutation Probability:     | 0.1                             |
# |Mutation:                 | Multiple_Bit_Flip_Mutation      |
# |Number of Bit Flips:      | 5                               |
# |Crossover Probability:    | 0.95                            |
# |Crossover:                | Uniform                         |
# |Elitism:                  | True                            |
#
# <br>
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.3055 USD$ |
# |Std. Fitness|0.0963 USD$  |
#
# ---

# %% [markdown]
# # Final Run
#
# |Parameter                 | Value                           |
# |--------------------------|---------------------------------|
# |Generations per Iterarion:| 30                              |
# |Population Size:          | 750                             |
# |Selection:                | Tournament                      |
# |Tournament Size:          | 4                               |
# |Mutation Probability:     | 0.1                             |
# |Mutation:                 | Multiple_Bit_Flip_Mutation      |
# |Number of Bit Flips:      | 5                               |
# |Crossover Probability:    | 0.95                            |
# |Crossover:                | Uniform                         |
# |Elitism:                  | True                            |

# %%
evolve_parameters = {
    "select": tournament,
    "tournament_k": 4,
    "gens": 30,
    "mut_prob": 0.1,
    "mutate": mutation,
    "mut_type": "multiple_bit_flip_mutation",
    "bit_flips": 5,
    "xo_prob": 0.95,
    "crossover": crossover,
    "xo_type": "uniform",
    "elitism": True
    }

results, product_count, table, nutri = evaluation(population_size=750, evolve_parameters=evolve_parameters)
# Out:
# Average - Fitness: 11.3477 USD$
# Standard Deviation - Fitness: 0.1414 USD$

# %%
plot_results(results, product_count, table, nutri)
# Out:
# C:\Users\janpa\AppData\Local\Temp\ipykernel_1880\576603859.py:81: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
#   ax2.set_yticks([])

# %% [markdown]
# **Conclusion**
#
# |Metric      |Score        |
# |------------|-----        |
# |Avg. Fitness|11.3477 USD$ |
# |Std. Fitness|0.1414 USD$  |
#
# ---
